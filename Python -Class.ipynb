# %%
#Array or List-Editable and allows duplicates
numarray=[2,4,34,56,72,2,5]
print(numarray)
chararray=['a',"Apple",'B','Boy',"C","Cat"]
print(chararray)
Mixedarrey=['Apple',"a",2,45,26,"John"]
print(Mixedarrey)
# Out:
# [2, 4, 34, 56, 72, 2, 5]
# ['a', 'Apple', 'B', 'Boy', 'C', 'Cat']
# ['Apple', 'a', 2, 45, 26, 'John']

# %%
array=[2,1,3,6,4,5]
print(array)
set={2,5,1,6}
print(set)
# Out:
# [2, 1, 3, 6, 4, 5]
# {1, 2, 5, 6}

# %%
#Tupples-Immutable/non editable
numtupple=(1,45,87,23,56,15,89,1)
print(numtupple)
Chartupple=('dog',"Apple",'A',"Sam")
print(Chartupple)
Mixedtupple=("apple",15,85,"Sam")
print(Mixedtupple)
# Out:
# (1, 45, 87, 23, 56, 15, 89, 1)
# ('dog', 'Apple', 'A', 'Sam')
# ('apple', 15, 85, 'Sam')

# %%
#Sets-Duplicates not allowed
numset={1,56,45,76,14,25}
print(numset)
Charset=('dog',"Apple",'A',"Sam")
print(Charset)
Mixedset={"Aaa",12,34}
print(Mixedset)
# Out:
# {1, 56, 25, 76, 45, 14}
# ('dog', 'Apple', 'A', 'Sam')
# {34, 12, 'Aaa'}

# %%
#Dictonary
dict_1={'Male':1,'Female':2}
print(dict_1)
# Out:
# {'Male': 1, 'Female': 2}

# %% [markdown]
# #image from websites
# ![image.png](attachment:image.png)

# %%
#List/array methods
numarray.append([50,48,45,25])  #adds elemnts at the end of the ist
print(numarray)
print(numarray.count(2))       #returns number of times the number appears
print(numarray.index(2))       # python starts count with 0. Gives the position of the number
numarray.insert(2,88)        #adds the elements to array at specific position
numarry
# Out:
# [2, 4, 34, 56, 72, 2, 5, [50, 48, 45, 25]]
# 2
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       5 print(numarray.index(2))       # python starts count with 0. Gives the position of the number
#       6 numarray.insert(2,88)        #adds the elements to array at specific position
# ----> 7 numarry
#
# NameError: name 'numarry' is not defined

# %%
numarray=[47,58,69,23,47,88,56,23,74]
numarray.sort()
numarray

# %%
#numarray.clear()    removes all the elements of the list
numarray.pop(3)       #removes element at specific position
print(numarray)
numarray.remove(47)   # removes first item of the duplicted value
print(numarray)

# %%
#libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import io
# %cd "C:\Users\chkee\Downloads\Python"

# %%
NYBnB=pd.read_excel("New York AirBnB.xlsx",sheet_name="New York AirBnB")
#NYBnB- Is the name assigned to the file of New York AirBnB.xlsx
#pd refers to library name
#read_excel()- predefined function. every function must have paranthesis
#or (). either paranthesis will be null or arguments within
# function synteax-library name.functionname()

# %%
NYBnB.info()    # To find out the data imported
# Class-Data frame-'pandas.core.frame.DataFrame'
# Total rows-41533
#Total columns-18

#Individual data variables-int 64,float 64,object or string,datetime 64 nos
#non-null highlights wheather the column has a missing varialles or not

# %%
#indexing or accessing specific rows or columns
#character indexing-accssing by column or variable name. Nmae must exactly match
#Numeric indexing-accssing by column or variable index number. Python starts with 0

# %%
 #character indexing-2 types
 # 1) dataframename.columnname
 #2) dataframename["columnname"]   used when variable name has space in between
 
NYBnB.price.head()   # head- by default takes 1st 5 rows of data

# %%
NYBnB["price"].head()

# %%
# character indexing multiple column/variable- dataframename[["var1","var2"]]
NYBnB[["price","minimum_nights","number_of_reviews"]].head(10)

# %%
#Numeric indexing- column number
NYBnB.iloc[:,9].head()  #:, before indicates column/variable selection

# %%
NYBnB.iloc[9].head() # without colon and coma it gives row details

# %%
#numeric indexing-Multicolumn
NYBnB.iloc[:,[9,10,11,14,17]].head()

# %%
#Numeric indexing- Multirow selection

NYBnB.iloc[[9,10,11,14,17]].head()

# %%
# Exploratory data analysis (EDA) - Desprictive statestics, Data visualization and data aggregation/grouping/wraggling
#EDA provides complete understanding of data

#Desprictive statestics - describe the data, Numeric variables-univariate statestice
#Measures of central tendency- Mean, Median, Mode
#Measures of dispersion-Variance and SD
#Measures of location- quartiles,percentiles and deciles
#Measures of assymentric- How cose data is normal distribution/bell curve,skewness and kurtosis


#Mean and median must be close to each other as mean gets distorted by the small or large values. IF mean is distorted median must be used
#SD must be lower and it doesnt have fixed range. It depends on mathematical values like tens,hundred,thousand etc
# positive skewness
#negative skewness
#Kurtosis

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
NYBnB.price.describe() 

# Describe-descriptive stst min,max,mean,med 50%,std,25%-Q1,75%-Q3

#High mean and SD so we need to consider Median i.e 131

# %%
print("skewness",NYBnB.price.skew())  #Inference- very high positive skewness and kurtosis which means there is distrotion in price
print("kurtosis",NYBnB.price.kurt())

# %%
NYBnB.columns  # name of all the columns

# %%
NYBnB[["minimum_nights","number_of_reviews"]].describe()

# %%
print("skewness",NYBnB[["minimum_nights","number_of_reviews"]].skew())
print("kurtosis",NYBnB[["minimum_nights","number_of_reviews"]].kurt())

# %%
#Univariate plots- Line,bar,stacked bar charts etc
#Pandas plots- dataframename.variablename.plot(kind="")
#kind= line or pie or bar etc charts

# 3 most imp charts
#1) Histogram- bar chart of frequency distribution table. Fequency distributon table 2columns
                                                            #a)class intervel- UL & LL
                                                              # b)Frequency
#2) Box plot-Based on quartiles. Q1,Q2,Q3 and interquartiles range are req
#highlights the skewness and most imp outliers
#outliers are the extreme valuesthat fall outside normal range
#minimum side-Q1-1.5*IQR (Intermediate quartile range)
#Maximum side-Q3+1.5*IQR

# 3) Density curve- based on standard Normal distribution formula

# %%
NYBnB.price.plot(kind='hist')  #Histogram

# %%
NYBnB.price.plot(kind='box',vert=False)   #positive skewness with too many outliners

# %%
NYBnB.price.plot(kind='density')  # Positive density

# %%
NYBnB.number_of_reviews.plot(kind='hist')

# %%
NYBnB.number_of_reviews.plot(kind='box',vert=False)

# %%
NYBnB.number_of_reviews.plot(kind='density')

# %%
#Non Numeric data- Only freq counts and cross tabulations
NYBnB.room_type.value_counts(dropna=False) # value_counts gives the count of room type with non null values(Dropna)

# %%
pd.set_option("display.max_rows",223)
NYBnB.neighbourhood.value_counts()

# %%
#top20 neighbourhood
NYBnB.neighbourhood.value_counts(20)

# %%
df=NYBnB.neighbourhood.value_counts().nlargest(20)     # bars are named as containers in the backend it can be named as any as per our comf
ab=df.plot.bar(color='green')
for container in ab.containers:
    ab.bar_label(container,fontsize=7,color='red')

# %%
#bottom 20
df=NYBnB.neighbourhood.value_counts().nsmallest(20)     # bars are named as containers in the backend it can be named as any as per our comf
ab=df.plot.bar(color='red')
for bars in ab.bars:
    ab.bars_label(bars,fontsize=7,color='green')

# %%
#cross tabulation- frequency table of 2 categorical variables
pd.crosstab(NYBnB.neighbourhood,NYBnB.room_type).nlargest(20,columns="Entire home/apt")

# %%
df=pd.crosstab(NYBnB.neighbourhood,NYBnB.room_type).nlargest(20,columns='Entire home/apt')
ax=df.plot.bar(stacked=True)
for i in ax.containers:
    ax.bar_label(i,fontsize=7,color='green',label_type="center")

# %%
d1=pd.crosstab(NYBnB.neighbourhood,NYBnB.room_type)

# %%
d1[(d1['Entire home/apt']>=500)]&[(d1['Entire home/apt']<=1000)]

# %%
NYBnB.room_type.value_counts().plot(kind="pie",autopct='%.1f%%')

# %%
#Data aggregation-Groupby() function
NYBnB.price.groupby(NYBnB.room_type).mean()
#left side of the groupby should be numiraical
#right side of groupby within paranthesis categorical variable
# stat func like mean,med,std dev,sum etc

# %%
NYBnB.price.groupby(NYBnB.room_type).mean().sort_values().plot(kind='bar')

# %%
NYBnB.price.groupby(NYBnB.neighbourhood).mean().sort_values(ascending=False)

# %%
#What is the avg number of reviews for each room type

np.round(NYBnB.number_of_reviews.groupby(NYBnB.room_type).mean(),2)

#np.round-(output,decimal)

# %%
# Median price for each room type
NYBnB.price.groupby(NYBnB.room_type).median()
